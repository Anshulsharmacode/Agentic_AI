# %% [markdown]
# Pydantic

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from pydantic import BaseModel , Field

# %%
model = ChatGoogleGenerativeAI(
    model= "gemini-2.5-flash",
    temperature=0.7
)

# %%
class Car(BaseModel):
    name:str=Field(description="this is car name ")
    model:str=Field(description="this is model")
    price:int = Field(description="this is car price ")

# %%
model_with_stru = model.with_structured_output(Car)
model_with_stru
# Out:
# RunnableBinding(bound=ChatGoogleGenerativeAI(output_version=None, profile={'name': 'Gemini 2.5 Flash', 'release_date': '2025-03-20', 'last_updated': '2025-06-05', 'open_weights': False, 'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True}, google_api_key=SecretStr('**********'), location=None, model='gemini-2.5-flash', client=<google.genai.client.Client object at 0x7e89f0539630>, default_metadata=(), model_kwargs={}), kwargs={'response_mime_type': 'application/json', 'response_json_schema': {'properties': {'name': {'description': 'this is car name ', 'title': 'Name', 'type': 'string'}, 'model': 
# ...

# %%
model_with_stru.invoke("give me name of expensive car in india")
# Out:
# Car(name='Rolls-Royce Phantom', model='Phantom VIII', price=100000000)

# %% [markdown]
# nested

# %%
class Actor(BaseModel):
    actor:str= Field(description="this is actor name , he is hero  "),
    villain:str = Field(description="this is villain against the actor")
    
class Movie(BaseModel):
    movie:str=Field(description="this is movie name "),
    character:list[Actor]
    year:str=Field(description="this is year of movie launch ")

# %%
response = model.with_structured_output(Movie)
# Out:
# /home/anshul/anaconda3/envs/astro/lib/python3.10/site-packages/pydantic/json_schema.py:2463: PydanticJsonSchemaWarning: Default value (FieldInfo(annotation=NoneType, required=True, description='this is movie namme '),) is not JSON serializable; excluding default from JSON schema [non-serializable-default]
#   warnings.warn(message, PydanticJsonSchemaWarning)
# /home/anshul/anaconda3/envs/astro/lib/python3.10/site-packages/pydantic/json_schema.py:2463: PydanticJsonSchemaWarning: Default value (FieldInfo(annotation=NoneType, required=True, description='this is actor name , he is hero  '),) is not JSON serializable; excluding default from JSON schema [non-serializable-default]
#   warnings.warn(message, PydanticJsonSchemaWarning)

# %%
response.invoke("what is movie conduct my salman khan")
# Out:
# Movie(movie='Dabangg', charcter=[Actor(actor='Salman Khan', villan='Sonu Sood')], year='2010')

# %% [markdown]
# TYPEDICT

# %% [markdown]
# Typedict provide similar alternative using python's built in typing . ideal when dont need runtime validation

# %%
from typing_extensions import TypedDict , Annotated

# %%
class Actor(TypedDict):
    actor:str
    villain:str 
    
class Movie(TypedDict):
    movie:str
    character:list[Actor]
    year:str

# %%
model_with = model.with_structured_output(Movie)

# %%
model_with.invoke("give me about Raone ")
# Out:
# {'movie': 'Ra.One',
#  'character': [{'actor': 'Arjun Rampal', 'villain': 'Ra.One'}],
#  'year': '2011'}

# %%
model.profile
# Out:
# {'name': 'Gemini 2.5 Flash',
#  'release_date': '2025-03-20',
#  'last_updated': '2025-06-05',
#  'open_weights': False,
#  'max_input_tokens': 1048576,
#  'max_output_tokens': 65536,
#  'text_inputs': True,
#  'image_inputs': True,
#  'audio_inputs': True,
#  'pdf_inputs': True,
#  'video_inputs': True,
#  'text_outputs': True,
#  'image_outputs': False,
#  'audio_outputs': False,
#  'video_outputs': False,
#  'reasoning_output': True,
#  'tool_calling': True,
#  'structured_output': True,
#  'attachment': True,
#  'temperature': True,
#  'image_url_inputs': True,
#  'image_tool_message': True,
#  'tool_choice': True}

# %% [markdown]
# USING DATACLASS

# %%
from dataclasses import dataclass
from langchain.agents import create_agent
import os

# %%
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
#
# NameError: name 'os' is not defined

# %%
model = create_agent(
    model="gemini-2.5-flash",
    response_format=
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 model = create_agent(
#       2     model="gemini-2.5-flash",
#       3     Key=os.getenv("GOOGLE_API_KEY"),
#       4 )
#
# TypeError: create_agent() got an unexpected keyword argument 'Key'
